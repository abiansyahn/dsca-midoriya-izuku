# %% [markdown]
# **DATA PREPARATION**

# %%
import pandas as pd
import numpy as np
import matplotlib

# %% [markdown]
# **MEMBACA DATA DENGAN PANDAS**

# %% [markdown]
# **CSV**

# %%
df_heart = pd.read_csv("/DSCA/Data Analysis with Pandas/heart.csv")
df_heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
stent = pd.read_csv("/DSCA/Data Analysis with Pandas/stent30.csv")
stent.head()
# Out:
#        group outcome
# 0  treatment  stroke
# 1  treatment  stroke
# 2  treatment  stroke
# 3  treatment  stroke
# 4  treatment  stroke

# %% [markdown]
# **JSON**

# %%
pd.read_json("/DSCA/Data Analysis with Pandas/owid-covid-latest.json")
# Out:
#                                                AFG      OWID_AFR  \
# continent                                     Asia          None
# location                               Afghanistan        Africa
# last_updated_date                       2021-06-23    2021-06-23
# total_cases                               107957.0     5281109.0
# new_cases                                   2208.0       32962.0
# new_cases_smoothed                        2095.571       25352.0
# total_deaths                                4366.0      139105.0
# new_deaths                                    73.0         516.0
# new_deaths_smoothed                         97.571       458.857
# total_cases_per_million                   2773.224      3939.368
# new_cases_per_million                        56.72        24.588
# new_cases_smoothed_per_million              53.832        18.911
# total_deaths_per_million                   112.155       103.763
# ...

# %%
covid = pd.read_json("/DSCA/Data Analysis with Pandas/owid-covid-latest.json", orient="index")
covid
# Out:
#          continent           location last_updated_date  total_cases  \
# AFG           Asia        Afghanistan        2021-06-23     107957.0
# OWID_AFR      None             Africa        2021-06-23    5281109.0
# ALB         Europe            Albania        2021-06-23     132497.0
# DZA         Africa            Algeria        2021-06-23     137049.0
# AND         Europe            Andorra        2021-06-23      13873.0
# ...            ...                ...               ...          ...
# WLF        Oceania  Wallis and Futuna        2021-06-21          NaN
# OWID_WRL      None              World        2021-06-23  179595550.0
# YEM           Asia              Yemen        2021-06-23       6898.0
# ZMB         Africa             Zambia        2021-06-23     137026.0
# ZWE         Africa           Zimbabwe        2021-06-23      43480.0
#
#           new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# AFG          2208.0            2095.571        4366.0        73.0
# ...

# %%
youtube_categories = pd.read_json("/DSCA/Data Analysis with Pandas/category.json", orient="columns")
youtube_categories
# Out:
#                                  kind                         etag  \
# 0   youtube#videoCategoryListResponse  _S1MAxBhP9n7eQUvtH1duuWAwbw
# 1   youtube#videoCategoryListResponse  _S1MAxBhP9n7eQUvtH1duuWAwbw
# 2   youtube#videoCategoryListResponse  _S1MAxBhP9n7eQUvtH1duuWAwbw
# 3   youtube#videoCategoryListResponse  _S1MAxBhP9n7eQUvtH1duuWAwbw
# 4   youtube#videoCategoryListResponse  _S1MAxBhP9n7eQUvtH1duuWAwbw
# 5   youtube#videoCategoryListResponse  _S1MAxBhP9n7eQUvtH1duuWAwbw
# 6   youtube#videoCategoryListResponse  _S1MAxBhP9n7eQUvtH1duuWAwbw
# 7   youtube#videoCategoryListResponse  _S1MAxBhP9n7eQUvtH1duuWAwbw
# 8   youtube#videoCategoryListResponse  _S1MAxBhP9n7eQUvtH1duuWAwbw
# 9   youtube#videoCategoryListResponse  _S1MAxBhP9n7eQUvtH1duuWAwbw
# 10  youtube#videoCategoryListResponse  _S1MAxBhP9n7eQUvtH1duuWAwbw
# 11  youtube#videoCategoryListResponse  _S1MAxBhP9n7eQUvtH1duuWAwbw
# 12  youtube#videoCategoryListResponse  _S1MAxBhP9n7eQUvtH1duuWAwbw
# ...

# %%
vaksinasi = pd.read_json("/DSCA/Data Analysis with Pandas/vaccinations.json", orient="values")
vaksinasi
# Out:
#                country  iso_code  \
# 0          Afghanistan       AFG
# 1               Africa  OWID_AFR
# 2              Albania       ALB
# 3              Algeria       DZA
# 4              Andorra       AND
# ..                 ...       ...
# 230  Wallis and Futuna       WLF
# 231              World  OWID_WRL
# 232              Yemen       YEM
# 233             Zambia       ZMB
# 234           Zimbabwe       ZWE
#
#                                                   data
# 0    [{'date': '2021-02-22', 'total_vaccinations': ...
# 1    [{'date': '2021-01-09', 'total_vaccinations': ...
# 2    [{'date': '2021-01-10', 'total_vaccinations': ...
# 3    [{'date': '2021-01-29', 'total_vaccinations': ...
# 4    [{'date': '2021-01-25', 'total_vaccinations': ...
# ..                                                 ...
# 230  [{'date': '2021-03-23', 'total_vaccinations': ...
# 231  [{'date': '2020-12-01', 'total_vaccinations': ...
# 232  [{'date': '2021-05-09', 'total_vaccinations': ...
# ...

# %% [markdown]
# **EXCEL**

# %% [markdown]
# KUIS

# %%
kuis_excel = pd.read_excel("/DSCA/Data Analysis with Pandas/whs2021_annex2_20210519.xlsx", sheet_name="Footnotes", index_col=0, header=None)
kuis_excel
# Out:
#                                                     1
# 0
# a   World population prospects: 2019 revision. New...
# b   Global health estimates 2019: Life expectancy,...
# c   WHO Member States with a population of less th...
# d   Trends in maternal mortality: 2000 to 2017: es...
# e   Joint WHO/UNICEF Interagency database 2021 of ...
# ..                                                ...
# bj  Estimate based on survey data. Females 16 year...
# bk  Coverage over 100% truncated to 99%. May indic...
# bl        Oedema data was considered in the analysis.
# bm   Survey data (subnational) indicate 80% coverage.
# bn  For high-income countries with no information ...
#
# [66 rows x 1 columns]

# %%
kuis_excel1 = pd.ExcelFile("/DSCA/Data Analysis with Pandas/whs2021_annex2_20210519.xlsx")
kuis_excel1

# %%
pd.ExcelFile.parse(kuis_excel1, sheet_name="Footnotes", header=None, usecols=[1])
# Out:
#                                                     1
# 0   World population prospects: 2019 revision. New...
# 1   Global health estimates 2019: Life expectancy,...
# 2   WHO Member States with a population of less th...
# 3   Trends in maternal mortality: 2000 to 2017: es...
# 4   Joint WHO/UNICEF Interagency database 2021 of ...
# ..                                                ...
# 61  Estimate based on survey data. Females 16 year...
# 62  Coverage over 100% truncated to 99%. May indic...
# 63        Oedema data was considered in the analysis.
# 64   Survey data (subnational) indicate 80% coverage.
# 65  For high-income countries with no information ...
#
# [66 rows x 1 columns]

# %% [markdown]
# **PENANGANAN KETAKLENGKAPAN DATA**

# %%
df_this = pd.DataFrame([[1, 2, 3, "None"], [None, None, 10, 4]])
df_this
# Out:
#      0    1   2     3
# 0  1.0  2.0   3  None
# 1  NaN  NaN  10     4

# %%
df_this.isna()
# Out:
#        0      1      2      3
# 0  False  False  False  False
# 1   True   True  False  False

# %%
df_this.isnull()
# Out:
#        0      1      2      3
# 0  False  False  False  False
# 1   True   True  False  False

# %%
grade_score = pd.DataFrame({"grade": ["A", "B", "undefined", "E", "B"], "score": [91, "-", 75, np.nan, 84]})
print(grade_score)

print(grade_score.grade.unique())
# Out:
#        grade score
# 0          A    91
# 1          B     -
# 2  undefined    75
# 3          E   NaN
# 4          B    84
# ['A' 'B' 'undefined' 'E']

# %%
#bagaiaman cara merubah value undefined?

# %% [markdown]
# **INSPEKSI DATA HILANG**

# %%
covid.isna().sum()
# Out:
# continent                                  9
# location                                   0
# last_updated_date                          0
# total_cases                               24
# new_cases                                 24
# new_cases_smoothed                        24
# total_deaths                              31
# new_deaths                                31
# new_deaths_smoothed                       24
# total_cases_per_million                   25
# new_cases_per_million                     25
# new_cases_smoothed_per_million            25
# total_deaths_per_million                  32
# new_deaths_per_million                    32
# new_deaths_smoothed_per_million           25
# reproduction_rate                         41
# icu_patients                             204
# icu_patients_per_million                 204
# hosp_patients                            198
# hosp_patients_per_million                198
# weekly_icu_admissions                    212
# ...

# %%
(covid.isna().sum() / covid.shape[0]) * 100
# Out:
# continent                                 4.000000
# location                                  0.000000
# last_updated_date                         0.000000
# total_cases                              10.666667
# new_cases                                10.666667
# new_cases_smoothed                       10.666667
# total_deaths                             13.777778
# new_deaths                               13.777778
# new_deaths_smoothed                      10.666667
# total_cases_per_million                  11.111111
# new_cases_per_million                    11.111111
# new_cases_smoothed_per_million           11.111111
# total_deaths_per_million                 14.222222
# new_deaths_per_million                   14.222222
# new_deaths_smoothed_per_million          11.111111
# reproduction_rate                        18.222222
# icu_patients                             90.666667
# icu_patients_per_million                 90.666667
# ...

# %% [markdown]
# KUIS

# %%
(covid.notna().sum(axis=0) / covid.shape[0]) * 100
# Out:
# continent                                 96.000000
# location                                 100.000000
# last_updated_date                        100.000000
# total_cases                               89.333333
# new_cases                                 89.333333
# new_cases_smoothed                        89.333333
# total_deaths                              86.222222
# new_deaths                                86.222222
# new_deaths_smoothed                       89.333333
# total_cases_per_million                   88.888889
# new_cases_per_million                     88.888889
# new_cases_smoothed_per_million            88.888889
# total_deaths_per_million                  85.777778
# new_deaths_per_million                    85.777778
# new_deaths_smoothed_per_million           88.888889
# reproduction_rate                         81.777778
# icu_patients                               9.333333
# icu_patients_per_million                   9.333333
# ...

# %%
(covid.notna().sum(axis=1) / covid.shape[1]) * 100
# Out:
# AFG         62.711864
# OWID_AFR    40.677966
# ALB         81.355932
# DZA         52.542373
# AND         66.101695
#               ...
# WLF         22.033898
# OWID_WRL    66.101695
# YEM         64.406780
# ZMB         83.050847
# ZWE         84.745763
# Length: 225, dtype: float64

# %% [markdown]
# **PENYARINGAN DATA**

# %%
print(covid[covid.isna()])
# Out:
#          continent location last_updated_date  total_cases  new_cases  \
# AFG            NaN      NaN               NaN          NaN        NaN
# OWID_AFR       NaN      NaN               NaN          NaN        NaN
# ALB            NaN      NaN               NaN          NaN        NaN
# DZA            NaN      NaN               NaN          NaN        NaN
# AND            NaN      NaN               NaN          NaN        NaN
# ...            ...      ...               ...          ...        ...
# WLF            NaN      NaN               NaN          NaN        NaN
# OWID_WRL       NaN      NaN               NaN          NaN        NaN
# YEM            NaN      NaN               NaN          NaN        NaN
# ZMB            NaN      NaN               NaN          NaN        NaN
# ZWE            NaN      NaN               NaN          NaN        NaN
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# **MENGHAPUS NILAI YANG HILANG**

# %%
col_percent_missing = covid.isna().sum() / covid.shape[0]
covid.loc[:, col_percent_missing <= .7]
# Out:
#          continent           location last_updated_date  total_cases  \
# AFG           Asia        Afghanistan        2021-06-23     107957.0
# OWID_AFR      None             Africa        2021-06-23    5281109.0
# ALB         Europe            Albania        2021-06-23     132497.0
# DZA         Africa            Algeria        2021-06-23     137049.0
# AND         Europe            Andorra        2021-06-23      13873.0
# ...            ...                ...               ...          ...
# WLF        Oceania  Wallis and Futuna        2021-06-21          NaN
# OWID_WRL      None              World        2021-06-23  179595550.0
# YEM           Asia              Yemen        2021-06-23       6898.0
# ZMB         Africa             Zambia        2021-06-23     137026.0
# ZWE         Africa           Zimbabwe        2021-06-23      43480.0
#
#           new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# AFG          2208.0            2095.571        4366.0        73.0
# ...

# %%
covid.loc[:, col_percent_missing >= .7]
# Out:
#           icu_patients  icu_patients_per_million  hosp_patients  \
# AFG                NaN                       NaN            NaN
# OWID_AFR           NaN                       NaN            NaN
# ALB                NaN                       NaN            NaN
# DZA                NaN                       NaN            NaN
# AND                NaN                       NaN            NaN
# ...                ...                       ...            ...
# WLF                NaN                       NaN            NaN
# OWID_WRL           NaN                       NaN            NaN
# YEM                NaN                       NaN            NaN
# ZMB                NaN                       NaN            NaN
# ZWE                NaN                       NaN            NaN
#
#           hosp_patients_per_million  weekly_icu_admissions  \
# AFG                             NaN                    NaN
# OWID_AFR                        NaN                    NaN
# ...

# %% [markdown]
# KUIS

# %%
covid
# Out:
#          continent           location last_updated_date  total_cases  \
# AFG           Asia        Afghanistan        2021-06-23     107957.0
# OWID_AFR      None             Africa        2021-06-23    5281109.0
# ALB         Europe            Albania        2021-06-23     132497.0
# DZA         Africa            Algeria        2021-06-23     137049.0
# AND         Europe            Andorra        2021-06-23      13873.0
# ...            ...                ...               ...          ...
# WLF        Oceania  Wallis and Futuna        2021-06-21          NaN
# OWID_WRL      None              World        2021-06-23  179595550.0
# YEM           Asia              Yemen        2021-06-23       6898.0
# ZMB         Africa             Zambia        2021-06-23     137026.0
# ZWE         Africa           Zimbabwe        2021-06-23      43480.0
#
#           new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# AFG          2208.0            2095.571        4366.0        73.0
# ...

# %%
covid["female_smokers"].isna()
# Out:
# AFG          True
# OWID_AFR     True
# ALB         False
# DZA         False
# AND         False
#             ...
# WLF          True
# OWID_WRL    False
# YEM         False
# ZMB         False
# ZWE         False
# Name: female_smokers, Length: 225, dtype: bool

# %%
no_female_male_smokers = covid.loc[(covid["female_smokers"].isna() == True) & (covid["male_smokers"].isna() == True)]
no_female_male_smokers
# Out:
#               continent                  location last_updated_date  \
# AFG                Asia               Afghanistan        2021-06-23
# OWID_AFR           None                    Africa        2021-06-23
# AGO              Africa                    Angola        2021-06-23
# AIA       North America                  Anguilla        2021-06-18
# ATG       North America       Antigua and Barbuda        2021-06-23
# ...                 ...                       ...               ...
# TCA       North America  Turks and Caicos Islands        2021-06-18
# TUV             Oceania                    Tuvalu        2021-06-15
# VAT              Europe                   Vatican        2021-06-23
# VEN       South America                 Venezuela        2021-06-23
# WLF             Oceania         Wallis and Futuna        2021-06-21
#
#           total_cases  new_cases  new_cases_smoothed  total_deaths  \
# AFG          107957.0     2208.0            2095.571        4366.0
# ...

# %%
testing_this = covid[covid["female_smokers"].isna() & covid["male_smokers"].isna()]
testing_this
# Out:
#               continent                  location last_updated_date  \
# AFG                Asia               Afghanistan        2021-06-23
# OWID_AFR           None                    Africa        2021-06-23
# AGO              Africa                    Angola        2021-06-23
# AIA       North America                  Anguilla        2021-06-18
# ATG       North America       Antigua and Barbuda        2021-06-23
# ...                 ...                       ...               ...
# TCA       North America  Turks and Caicos Islands        2021-06-18
# TUV             Oceania                    Tuvalu        2021-06-15
# VAT              Europe                   Vatican        2021-06-23
# VEN       South America                 Venezuela        2021-06-23
# WLF             Oceania         Wallis and Futuna        2021-06-21
#
#           total_cases  new_cases  new_cases_smoothed  total_deaths  \
# AFG          107957.0     2208.0            2095.571        4366.0
# ...

# %%
col_percent_non_missing = covid.notna().sum() / covid.shape[0]
covid.loc[:, col_percent_non_missing >= .8]
# Out:
#          continent           location last_updated_date  total_cases  \
# AFG           Asia        Afghanistan        2021-06-23     107957.0
# OWID_AFR      None             Africa        2021-06-23    5281109.0
# ALB         Europe            Albania        2021-06-23     132497.0
# DZA         Africa            Algeria        2021-06-23     137049.0
# AND         Europe            Andorra        2021-06-23      13873.0
# ...            ...                ...               ...          ...
# WLF        Oceania  Wallis and Futuna        2021-06-21          NaN
# OWID_WRL      None              World        2021-06-23  179595550.0
# YEM           Asia              Yemen        2021-06-23       6898.0
# ZMB         Africa             Zambia        2021-06-23     137026.0
# ZWE         Africa           Zimbabwe        2021-06-23      43480.0
#
#           new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# AFG          2208.0            2095.571        4366.0        73.0
# ...

# %%
col_percent_non_missing
# Out:
# continent                                0.960000
# location                                 1.000000
# last_updated_date                        1.000000
# total_cases                              0.893333
# new_cases                                0.893333
# new_cases_smoothed                       0.893333
# total_deaths                             0.862222
# new_deaths                               0.862222
# new_deaths_smoothed                      0.893333
# total_cases_per_million                  0.888889
# new_cases_per_million                    0.888889
# new_cases_smoothed_per_million           0.888889
# total_deaths_per_million                 0.857778
# new_deaths_per_million                   0.857778
# new_deaths_smoothed_per_million          0.888889
# reproduction_rate                        0.817778
# icu_patients                             0.093333
# icu_patients_per_million                 0.093333
# hosp_patients                            0.120000
# ...

# %%
covid.dropna(subset=["female_smokers", "male_smokers"], how="all")
# Out:
#               continent   location last_updated_date  total_cases  new_cases  \
# ALB              Europe    Albania        2021-06-23     132497.0        1.0
# DZA              Africa    Algeria        2021-06-23     137049.0      370.0
# AND              Europe    Andorra        2021-06-23      13873.0        9.0
# ARG       South America  Argentina        2021-06-23    4326101.0    27319.0
# ARM                Asia    Armenia        2021-06-23     224430.0      100.0
# ...                 ...        ...               ...          ...        ...
# VNM                Asia    Vietnam        2021-06-23      13989.0      207.0
# OWID_WRL           None      World        2021-06-23  179595550.0   437255.0
# YEM                Asia      Yemen        2021-06-23       6898.0        6.0
# ZMB              Africa     Zambia        2021-06-23     137026.0     3367.0
# ZWE              Africa   Zimbabwe        2021-06-23      43480.0      766.0
#
# ...

# %% [markdown]
# **MENGISI NILAI YANG HILANG**

# %%
print(covid.handwashing_facilities.fillna(np.mean(covid.handwashing_facilities)))
print(covid.fillna(
    {"handwashing_facilities": covid.handwashing_facilities.mean(), "life_expectancy": covid.life_expectancy.median()}
)[["handwashing_facilities", "life_expectancy"]])
# Out:
# AFG         37.746000
# OWID_AFR    50.270832
# ALB         50.270832
# DZA         83.741000
# AND         50.270832
#               ...
# WLF         50.270832
# OWID_WRL    60.130000
# YEM         49.542000
# ZMB         13.938000
# ZWE         36.791000
# Name: handwashing_facilities, Length: 225, dtype: float64
#           handwashing_facilities  life_expectancy
# AFG                    37.746000            64.83
# OWID_AFR               50.270832            74.62
# ALB                    50.270832            78.57
# DZA                    83.741000            76.88
# AND                    50.270832            83.73
# ...                          ...              ...
# WLF                    50.270832            79.94
# OWID_WRL               60.130000            72.58
# YEM                    49.542000            66.12
# ZMB                    13.938000            63.89
# ZWE                    36.791000            61.49
#
# [225 rows x 2 columns]

# %%
#kenapa harus ada [[]]?

# %%
covid.handwashing_facilities.interpolate()
# Out:
# AFG         37.746000
# OWID_AFR    53.077667
# ALB         68.409333
# DZA         83.741000
# AND         55.202500
#               ...
# WLF         72.988500
# OWID_WRL    60.130000
# YEM         49.542000
# ZMB         13.938000
# ZWE         36.791000
# Name: handwashing_facilities, Length: 225, dtype: float64

# %% [markdown]
# **PEMROSESAN DERET WAKTU DALAM PANDAS**

# %% [markdown]
# **Deret Waktu dalam Pandas**

# %%
print(pd.to_datetime("2021-08-17"))
print(pd.to_datetime("17 August 2021"))
# Out:
# 2021-08-17 00:00:00
# 2021-08-17 00:00:00

# %%
pd.date_range("2021 August 1", "2021 August 31")
# Out:
# DatetimeIndex(['2021-08-01', '2021-08-02', '2021-08-03', '2021-08-04',
#                '2021-08-05', '2021-08-06', '2021-08-07', '2021-08-08',
#                '2021-08-09', '2021-08-10', '2021-08-11', '2021-08-12',
#                '2021-08-13', '2021-08-14', '2021-08-15', '2021-08-16',
#                '2021-08-17', '2021-08-18', '2021-08-19', '2021-08-20',
#                '2021-08-21', '2021-08-22', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-28',
#                '2021-08-29', '2021-08-30', '2021-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range("2021 August 1", periods=40, freq="D")
# Out:
# DatetimeIndex(['2021-08-01', '2021-08-02', '2021-08-03', '2021-08-04',
#                '2021-08-05', '2021-08-06', '2021-08-07', '2021-08-08',
#                '2021-08-09', '2021-08-10', '2021-08-11', '2021-08-12',
#                '2021-08-13', '2021-08-14', '2021-08-15', '2021-08-16',
#                '2021-08-17', '2021-08-18', '2021-08-19', '2021-08-20',
#                '2021-08-21', '2021-08-22', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-28',
#                '2021-08-29', '2021-08-30', '2021-08-31', '2021-09-01',
#                '2021-09-02', '2021-09-03', '2021-09-04', '2021-09-05',
#                '2021-09-06', '2021-09-07', '2021-09-08', '2021-09-09'],
#               dtype='datetime64[ns]', freq='D')

# %%
dt_naive = pd.date_range("2021 August 1", periods=24, freq="2H")
dt_aware = pd.date_range("2021 August 1", periods=24, freq="2H", tz="Asia/Jakarta")

print(dt_aware)
print(dt_aware.tz_convert("UTC"))
print(dt_naive.tz_localize("UTC").tz_convert("Asia/Jakarta"))
# Out:
# DatetimeIndex(['2021-08-01 00:00:00+07:00', '2021-08-01 02:00:00+07:00',
#                '2021-08-01 04:00:00+07:00', '2021-08-01 06:00:00+07:00',
#                '2021-08-01 08:00:00+07:00', '2021-08-01 10:00:00+07:00',
#                '2021-08-01 12:00:00+07:00', '2021-08-01 14:00:00+07:00',
#                '2021-08-01 16:00:00+07:00', '2021-08-01 18:00:00+07:00',
#                '2021-08-01 20:00:00+07:00', '2021-08-01 22:00:00+07:00',
#                '2021-08-02 00:00:00+07:00', '2021-08-02 02:00:00+07:00',
#                '2021-08-02 04:00:00+07:00', '2021-08-02 06:00:00+07:00',
#                '2021-08-02 08:00:00+07:00', '2021-08-02 10:00:00+07:00',
#                '2021-08-02 12:00:00+07:00', '2021-08-02 14:00:00+07:00',
#                '2021-08-02 16:00:00+07:00', '2021-08-02 18:00:00+07:00',
#                '2021-08-02 20:00:00+07:00', '2021-08-02 22:00:00+07:00'],
#               dtype='datetime64[ns, Asia/Jakarta]', freq='2H')
# ...

# %% [markdown]
# **Pengindeksan Deret Waktu**

# %%
covid.last_updated_date
# Out:
# AFG         2021-06-23
# OWID_AFR    2021-06-23
# ALB         2021-06-23
# DZA         2021-06-23
# AND         2021-06-23
#                ...
# WLF         2021-06-21
# OWID_WRL    2021-06-23
# YEM         2021-06-23
# ZMB         2021-06-23
# ZWE         2021-06-23
# Name: last_updated_date, Length: 225, dtype: object

# %% [markdown]
# **Komponen Waktu dan Tanggal**

# %%
covid["last_updated_date"] = pd.to_datetime(covid["last_updated_date"])

# %%
covid["last_updated_date"].dt.day_name()
# Out:
# AFG         Wednesday
# OWID_AFR    Wednesday
# ALB         Wednesday
# DZA         Wednesday
# AND         Wednesday
#               ...
# WLF            Monday
# OWID_WRL    Wednesday
# YEM         Wednesday
# ZMB         Wednesday
# ZWE         Wednesday
# Name: last_updated_date, Length: 225, dtype: object

# %%
print(covid.last_updated_date)
# Out:
# AFG        2021-06-23
# OWID_AFR   2021-06-23
# ALB        2021-06-23
# DZA        2021-06-23
# AND        2021-06-23
#               ...
# WLF        2021-06-21
# OWID_WRL   2021-06-23
# YEM        2021-06-23
# ZMB        2021-06-23
# ZWE        2021-06-23
# Name: last_updated_date, Length: 225, dtype: datetime64[ns]

# %%
covid.last_updated_date.dt.month
# Out:
# AFG         6
# OWID_AFR    6
# ALB         6
# DZA         6
# AND         6
#            ..
# WLF         6
# OWID_WRL    6
# YEM         6
# ZMB         6
# ZWE         6
# Name: last_updated_date, Length: 225, dtype: int64

# %% [markdown]
# KUIS

# %%
all_last_update = covid.last_updated_date.values
all_last_update
# Out:
# array(['2021-06-23T00:00:00.000000000', '2021-06-23T00:00:00.000000000',
#        '2021-06-23T00:00:00.000000000', '2021-06-23T00:00:00.000000000',
#        '2021-06-23T00:00:00.000000000', '2021-06-23T00:00:00.000000000',
#        '2021-06-18T00:00:00.000000000', '2021-06-23T00:00:00.000000000',
#        '2021-06-23T00:00:00.000000000', '2021-06-23T00:00:00.000000000',
#        '2021-06-23T00:00:00.000000000', '2021-06-23T00:00:00.000000000',
#        '2021-06-23T00:00:00.000000000', '2021-06-23T00:00:00.000000000',
#        '2021-06-23T00:00:00.000000000', '2021-06-23T00:00:00.000000000',
#        '2021-06-23T00:00:00.000000000', '2021-06-23T00:00:00.000000000',
#        '2021-06-23T00:00:00.000000000', '2021-06-23T00:00:00.000000000',
#        '2021-06-23T00:00:00.000000000', '2021-06-23T00:00:00.000000000',
#        '2021-06-23T00:00:00.000000000', '2021-06-14T00:00:00.000000000',
#        '2021-06-23T00:00:00.000000000', '2021-06-23T00:00:00.000000000',
# ...

# %%
max_last_update = np.max(all_last_update)
max_last_update
# Out:
# numpy.datetime64('2021-06-23T00:00:00.000000000')

# %%
data_not_updated = covid[covid["last_updated_date"] < max_last_update]
data_not_updated
# Out:
#          continent                   location last_updated_date  total_cases  \
# AIA  North America                   Anguilla        2021-06-18          NaN
# BMU  North America                    Bermuda        2021-06-14          NaN
# VGB  North America     British Virgin Islands        2021-06-18          NaN
# CYM  North America             Cayman Islands        2021-06-22          NaN
# COK        Oceania               Cook Islands        2021-06-21          NaN
# FRO         Europe             Faeroe Islands        2021-06-22          NaN
# PYF        Oceania           French Polynesia        2021-06-21          NaN
# GIB         Europe                  Gibraltar        2021-06-21          NaN
# GGY         Europe                   Guernsey        2021-06-22          NaN
# JEY         Europe                     Jersey        2021-06-16          NaN
# MSR  North America                 Montserrat        2021-06-18          NaN
# ...

# %%
data_updated_after_20_july = covid[covid["last_updated_date"] > "2021-06-20"]
data_updated_after_20_july
# Out:
#          continent           location last_updated_date  total_cases  \
# AFG           Asia        Afghanistan        2021-06-23     107957.0
# OWID_AFR      None             Africa        2021-06-23    5281109.0
# ALB         Europe            Albania        2021-06-23     132497.0
# DZA         Africa            Algeria        2021-06-23     137049.0
# AND         Europe            Andorra        2021-06-23      13873.0
# ...            ...                ...               ...          ...
# WLF        Oceania  Wallis and Futuna        2021-06-21          NaN
# OWID_WRL      None              World        2021-06-23  179595550.0
# YEM           Asia              Yemen        2021-06-23       6898.0
# ZMB         Africa             Zambia        2021-06-23     137026.0
# ZWE         Africa           Zimbabwe        2021-06-23      43480.0
#
#           new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# AFG          2208.0            2095.571        4366.0        73.0
# ...

# %% [markdown]
# **Pengambilan Sample Ulang**

# %%
data = pd.DataFrame(np.random.randint(0, 500, len(dt_naive)), columns=["score"], index=dt_naive)
display(data)
print(data.resample("4H").sum())
print(data.resample("D").mean())
# Out:
#                      score
# 2021-08-01 00:00:00     43
# 2021-08-01 02:00:00    439
# 2021-08-01 04:00:00     26
# 2021-08-01 06:00:00    265
# 2021-08-01 08:00:00    243
# 2021-08-01 10:00:00     59
# 2021-08-01 12:00:00    405
# 2021-08-01 14:00:00     72
# 2021-08-01 16:00:00    239
# 2021-08-01 18:00:00    379
# 2021-08-01 20:00:00    233
# 2021-08-01 22:00:00    395
# 2021-08-02 00:00:00    419
# 2021-08-02 02:00:00    226
# 2021-08-02 04:00:00    480
# 2021-08-02 06:00:00    262
# 2021-08-02 08:00:00    407
# 2021-08-02 10:00:00    111
# 2021-08-02 12:00:00    218
# 2021-08-02 14:00:00    360
# 2021-08-02 16:00:00    443
# 2021-08-02 18:00:00    307
# 2021-08-02 20:00:00    167
# 2021-08-02 22:00:00     12
#                      score
# 2021-08-01 00:00:00    482
# 2021-08-01 04:00:00    291
# 2021-08-01 08:00:00    302
# 2021-08-01 12:00:00    477
# 2021-08-01 16:00:00    618
# 2021-08-01 20:00:00    628
# 2021-08-02 00:00:00    645
# 2021-08-02 04:00:00    742
# ...

# %% [markdown]
# **TRANSFORMASI DATA**

# %%
alice = pd.read_csv("/DSCA/Data Analysis with Pandas/words.txt", header=None)

# %%
alice.columns = ["text"]

# %%
alice["len_text"] = alice.text.str.len()
alice["digit_exist"] = alice.text.str.isdigit()

# %%
alice
# Out:
#              text  len_text  digit_exist
# 0           Alice         5        False
# 1             was         3        False
# 2       beginning         9        False
# 3              to         2        False
# 4             get         3        False
# 5            very         4        False
# 6           tired         5        False
# 7              of         2        False
# 8         sitting         7        False
# 9              by         2        False
# 10            her         3        False
# 11         sister         6        False
# 12           bank         4        False
# 13         having         6        False
# 14        nothing         7        False
# 15           Once         4        False
# 16          twice         5        False
# 17            she         3        False
# 18            had         3        False
# 19         peeped         6        False
# 20           into         4        False
# 21            the         3        False
# ...

# %%
alice["is_digit"] = alice.digit_exist.apply(lambda b: int(b))

# %%
alice
# Out:
#              text  len_text  digit_exist  is_digit
# 0           Alice         5        False         0
# 1             was         3        False         0
# 2       beginning         9        False         0
# 3              to         2        False         0
# 4             get         3        False         0
# 5            very         4        False         0
# 6           tired         5        False         0
# 7              of         2        False         0
# 8         sitting         7        False         0
# 9              by         2        False         0
# 10            her         3        False         0
# 11         sister         6        False         0
# 12           bank         4        False         0
# 13         having         6        False         0
# 14        nothing         7        False         0
# 15           Once         4        False         0
# 16          twice         5        False         0
# ...

# %%
alice["len_percentage"] = alice.len_text.apply(lambda n: n/alice.len_text.sum())

# %%
alice.head()
# Out:
#         text  len_text  digit_exist  is_digit  len_percentage
# 0      Alice         5        False         0        0.022727
# 1        was         3        False         0        0.013636
# 2  beginning         9        False         0        0.040909
# 3         to         2        False         0        0.009091
# 4        get         3        False         0        0.013636

# %% [markdown]
# **Grouping**

# %%
df_group = pd.DataFrame(
    [
        ("bird", "Falconiformes", 389.0),
        ("bird", "Psittaciformes", 24.0),
        ("mammal", "Carnivora", 80.2),
        ("mammal", "Primates", np.nan),
        ("mammal", "Carnivora", 58),
    ],
    index=["falcon", "parrot", "lion", "monkey", "leopard"],
    columns=("class", "order", "max_speed")
)

# %%
df_group
# Out:
#           class           order  max_speed
# falcon     bird   Falconiformes      389.0
# parrot     bird  Psittaciformes       24.0
# lion     mammal       Carnivora       80.2
# monkey   mammal        Primates        NaN
# leopard  mammal       Carnivora       58.0

# %%
grouped1 = df_group.groupby("class")

# %%
grouped1.head()
# Out:
#           class           order  max_speed
# falcon     bird   Falconiformes      389.0
# parrot     bird  Psittaciformes       24.0
# lion     mammal       Carnivora       80.2
# monkey   mammal        Primates        NaN
# leopard  mammal       Carnivora       58.0

# %%
grouped2 = df_group.groupby("order", axis="columns")
grouped2.head()
# Out:
#           class           order  max_speed
# falcon     bird   Falconiformes      389.0
# parrot     bird  Psittaciformes       24.0
# lion     mammal       Carnivora       80.2
# monkey   mammal        Primates        NaN
# leopard  mammal       Carnivora       58.0

# %%
grouped3 = df_group.groupby(["class", "order"])
grouped3.head()
# Out:
#           class           order  max_speed
# falcon     bird   Falconiformes      389.0
# parrot     bird  Psittaciformes       24.0
# lion     mammal       Carnivora       80.2
# monkey   mammal        Primates        NaN
# leopard  mammal       Carnivora       58.0

# %% [markdown]
# **PIVOTING**
